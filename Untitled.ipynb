# %% [markdown]
# #  Gaussian Mixture Models
#
# For a set of given customers. If you built a game and you want to predict whether the customers would play the Game or not on the basis of the single data point (Feature) given which is the amount of money the user has spent in this game.In such tpe of Prediction Gaussian mixture could be a useful model
# This model is used Globally for Generative Unsupervised learning or clustering and is also called EM clustering,  which stands for Expectation Maximization Clustering.
# The optimization technique works with the idea. For a given dataset, each point is generated by the combining Linearly multiple Gaussian Functions.

# %% [markdown]
# Before starting with the Guassian Mixture Model. Let us take a breif of Gaussian.
#
# What is Gaussian?
# It is the Distribution of various outcomes of the experiment and the probability associated with each outcome. The Gaissian has a Bell curve Graphical representation. In the Gaussion Distribution we have the data which falls half on the Left of it and and remaining on the right of it. Thus, it is an even Distribution. To Deifne the Gaussian Distribution we required mean and the standard Deviation.
#
# [ Recaller - ]
#
# Mean - It is the average of all data points.
#
# Variance - It is defined as the sum of the squares of the differences between the each data value and then divided by the mean.
#
# Standard Deviation - It is the square root of variance.
#
# ## If we have a dataset in which the data points is increasing, has a peak and then decreasing then Gaussian Distribution could be a good fit.

# %%
#  Formula for Gaussian Distribution

from IPython.display import Image
Image ('/home/prachi/Desktop/gm1.jpg')

# %% [markdown]
# Gaussian Mixture Model is a probablitiy distribution function which contains Multiple Probability Distribution (Number of peaks)
# In Gaussian Distribution Function we do not use Standard Deviation, Instead we use Covariance Matrix (2D).

# %% [markdown]
# Why we use Covariance Matrix ?
#
# THe Covariance are termend as the the changes in one Variable(Data Points) associated with the changes in the other variable. ( When we have a large number of dataset Covariance gives us a better result than the Standard Deviation)

# %%
# Formula for Covariance Matrix is- 


from IPython.display import Image
Image ('/home/prachi/Desktop/gm5.png')

# %% [markdown]
#  Now let us take an example and understand it with the help of the code.
#
#  Demo -
#
# We implement the Gaussian mixture model to predict Santander Customer Transaction Prediction data.

# %%
# importig the librabries
import pandas as pd
import numpy as np

# %%
# IMporting the Dataset

db = pd.read_csv('train.csv')

# %%
db.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %%
db.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %% [markdown]
# By describing to the dataset it has given the clear picture of all the factors such as mean, median, etc for all the features. It helps  in understanding the importance of the features.

# %%
db.tail()
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# 199995  11.6081  5.6709  15.1516  ...   6.1415  13.2305   3.9901   0.9388
# 199996 -10.5628  5.8802  21.5940  ...   4.9611   4.6549   0.6998   1.8341
# 199997  -5.4086  4.5555  21.5571  ...   4.0651   5.4414   3.1032   4.8793
# 199998   0.5339  6.0479  17.0152  ...   2.6840   8.6587   2.7337  11.1178
# 199999   0.3488  5.2839  15.2058  ...   8.9842   1.6893   0.1276   0.3766
#
#         var_194  var_195  var_196  var_197  var_198  var_199
# ...

# %% [markdown]
# The tail would give a breifing of availability of the variables in all the columns.

# %%
# Now let us find the missing value if any
db.info()
total = db.isnull().sum().sort_values(ascending=False)
percent = (db.isnull().sum()/db.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB
#          Total  Percent
# var_199      0      0.0
# var_61       0      0.0
# var_71       0      0.0
# var_70       0      0.0
# var_69       0      0.0
# ...        ...      ...
# var_129      0      0.0
# var_128      0      0.0
# var_127      0      0.0
# var_126      0      0.0
# ID_code      0      0.0
#
# [202 rows x 2 columns]

# %% [markdown]
# Hence there are no null values.
#
# This was the basic breifing of the data.

# %%
#For plotting
import matplotlib.pyplot as plt
#for matrix math
import numpy as np
#for normalization + probability density function computation
from scipy import stats
#for plotting
import seaborn as sns

# %%
#Return evenly spaced numbers over a specified interval.
x = np.linspace(start=-10, stop=10, num=1000)
#A normal continuous random variable.
#The location (loc) keyword specifies the mean. The scale (scale) keyword specifies the standard deviation.
y = stats.norm.pdf(x, loc=0, scale=1.5) 
plt.plot(x, y)

# %% [markdown]
# This a bell curverd plot which has a peak value and clearly shows the Graph between the mean and the Standard Deviation ( Gaussian Distribution)

# %%
# Now let us plot the histogram of all the datapoints

class Gaussian:
    "Model univariate Gaussian"
    def __init__(self, mu, sigma):
        #mean and standard deviation
        self.mu = mu
        self.sigma = sigma

    #probability density function
    def pdf(self, datum):
        "Probability of a data point given the current parameters"
        u = (datum - self.mu) / abs(self.sigma)
        y = (1 / (sqrt(2 * pi) * abs(self.sigma))) * exp(-u * u / 2)
        return y
    #printing model values
    def __repr__(self):
        return 'Gaussian({0:4.6}, {1:4.6})'.format(self.mu, self.sigma)

# %%
best_single = Gaussian(np.mean(db), np.std(db))
print('Best single Gaussian: μ = {:.2}, σ = {:.2}'.format(best_single.mu, best_single.sigma))
